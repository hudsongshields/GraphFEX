# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Adj = pd.read_csv('BA_Nnodes100_Adj.csv').values
nodes = Adj.shape[0]
degrees = np.sum(Adj != 0, axis=1)
avg_degree = np.mean(degrees)
print(f"Average degree: {avg_degree}")
# Out:
# Average degree: 7.212121212121212

# %%
data = pd.read_csv('HR_timeseries_BA_deg_7_1_SNR_45.csv')
print(data.shape)
# Out:
# (49999, 300)

# %%
data = data.reshape(len(data), nodes, -1)
